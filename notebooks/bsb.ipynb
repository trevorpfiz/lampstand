# %%
import json
import os

from usfm_grammar import USFMParser

USFM_FOLDER = "data/bsb_usfm"
usfm_files = [
    os.path.join(USFM_FOLDER, file)
    for file in os.listdir(USFM_FOLDER)
    if file.endswith(".usfm")
]

# %%
bible_data = {}

for file in usfm_files:
    with open(file, "r", encoding="utf-8") as f:
        content = f.read()
        parser = USFMParser(content)

        # Check for errors
        if parser.errors:
            print(f"Errors in file {file}: {parser.errors}")
        else:
            # Convert to dictionary (USJ format)
            bible_data[file] = parser.to_usj()
# Out:
# Errors in file data/bsb_usfm/38ZECBSB.usfm: [('At Point(row=553, column=0)', '\\d\n\\v 1 This is the burden of the word of the LORD concerning Israel.'), ('At Point(row=554, column=65)', '.')]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 13
#      10     print(f"Errors in file {file}: {parser.errors}")
#      11 else:
#      12     # Convert to dictionary (USJ format)
# ---> 13     bible_data[file] = parser.to_usj()
#
# File ~/projects/lampstand/notebooks/.venv/lib/python3.13/site-packages/usfm_grammar/usfm_parser.py:167, in USFMParser.to_usj(self, exclude_markers, include_markers, ignore_errors, combine_texts)
#     165 try:
#     166     usj_generator = USJGenerator(USFM_LANGUAGE, self.usfm_bytes, json_root_obj)
# --> 167     usj_generator.node_2_usj(self.syntax_tree, json_root_obj)
#     168 except Exception as exe:
#     169     message = "Unable to do the conversion. "
#
# File ~/projects/lampstand/notebooks/.venv/lib/python3.13/site-packages/usfm_grammar/usj_generator.py:340, in USJGenerator.node_2_usj(self, node, parent_json_obj)
#     338 elif len(node.children)>0:
#     339     for child in node.children:
# --> 340         self.node_2_usj(child, parent_json_obj)
#
# File ~/projects/lampstand/notebooks/.venv/lib/python3.13/site-packages/usfm_grammar/usj_generator.py:302, in USJGenerator.node_2_usj(self, node, parent_json_obj)
#     300     self.node_2_usj_id(node, parent_json_obj)
#     301 elif node.type == "chapter":
# --> 302     self.node_2_usj_chapter(node,parent_json_obj)
#     303 elif node.type in ["cl", "cp", "cd", "vp"]:
#     304     self.node_2_usj_generic(node, parent_json_obj)
#
# File ~/projects/lampstand/notebooks/.venv/lib/python3.13/site-packages/usfm_grammar/usj_generator.py:98, in USJGenerator.node_2_usj_chapter(self, node, parent_json_obj)
#      96     self.node_2_usj_c(child,parent_json_obj)
#      97 else:
# ---> 98     self.node_2_usj(child, parent_json_obj)
#
# File ~/projects/lampstand/notebooks/.venv/lib/python3.13/site-packages/usfm_grammar/usj_generator.py:313, in USJGenerator.node_2_usj(self, node, parent_json_obj)
#     311         self.node_2_usj(child, parent_json_obj)
#     312 elif node.type in ['paragraph', 'pi', "ph"]:
# --> 313     self.node_2_usj_para(node, parent_json_obj)
#     314 elif node.type in self.NOTE_MARKERS:
#     315     self.node_2_usj_notes(node, parent_json_obj)
#
# File ~/projects/lampstand/notebooks/.venv/lib/python3.13/site-packages/usfm_grammar/usj_generator.py:151, in USJGenerator.node_2_usj_para(self, node, parent_json_obj)
#     149         para_json_obj = {"type": "para", "marker":para_marker, "content":[]}
#     150         for child in para_tag_cap[0].children[1:]:
# --> 151             self.node_2_usj(child, para_json_obj)
#     152         parent_json_obj['content'].append(para_json_obj)
#     153 elif node.type in ['pi', "ph"]:
#
# File ~/projects/lampstand/notebooks/.venv/lib/python3.13/site-packages/usfm_grammar/usj_generator.py:308, in USJGenerator.node_2_usj(self, node, parent_json_obj)
#     306     self.node_2_usj_ca_va(node, parent_json_obj)
#     307 elif node.type == "v":
# --> 308     self.node_2_usj_verse(node, parent_json_obj)
#     309 elif node.type == "verseText":
#     310     for child in node.children:
#
# File ~/projects/lampstand/notebooks/.venv/lib/python3.13/site-packages/usfm_grammar/usj_generator.py:118, in USJGenerator.node_2_usj_verse(self, node, parent_json_obj)
#     116         vp_text = self.usfm[tupl[0].start_byte:tupl[0].end_byte].decode('utf-8')
#     117         v_json_obj['pubnumber'] = vp_text.strip()
# --> 118 ref = str(self.findlast_from_json(self.json_root_obj, "chapter")['sid'])+ ":"+ verse_num
#     119 v_json_obj['number'] = verse_num.strip()
#     120 v_json_obj['sid'] = ref.strip()
#
# File ~/projects/lampstand/notebooks/.venv/lib/python3.13/site-packages/usfm_grammar/usj_generator.py:42, in USJGenerator.findlast_from_json(self, json_obj, type_value)
#      40 if isinstance(child, str):
#      41     continue
# ---> 42 child_output = self.findlast_from_json(child, type_value)
#      43 if child_output is not None:
#      44     output = child_output
#
# File ~/projects/lampstand/notebooks/.venv/lib/python3.13/site-packages/usfm_grammar/usj_generator.py:42, in USJGenerator.findlast_from_json(self, json_obj, type_value)
#      40 if isinstance(child, str):
#      41     continue
# ---> 42 child_output = self.findlast_from_json(child, type_value)
#      43 if child_output is not None:
#      44     output = child_output
#
# File ~/projects/lampstand/notebooks/.venv/lib/python3.13/site-packages/usfm_grammar/usj_generator.py:31, in USJGenerator.findlast_from_json(self, json_obj, type_value)
#      28     else:
#      29         self.json_root_obj = usj_root_obj
# ---> 31 def findlast_from_json(self, json_obj, type_value):
#      32     '''Traverse the given JSON and list all elements with given value in type field'''
#      33     output = None
#
# KeyboardInterrupt:

# %%
print(json.dumps(bible_data[usfm_files[0]], indent=4))
# Out:
# {
#     "type": "USJ",
#     "version": "3.1",
#     "content": [
#         {
#             "type": "book",
#             "marker": "id",
#             "content": [
#                 "- Berean Study Bible"
#             ],
#             "code": "RUT"
#         },
#         {
#             "type": "para",
#             "marker": "h",
#             "content": [
#                 "Ruth\n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "toc1",
#             "content": [
#                 "Ruth\n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "mt1",
#             "content": [
#                 "Ruth\n"
#             ]
#         },
#         {
#             "type": "chapter",
#             "marker": "c",
#             "number": "1",
#             "sid": "RUT 1"
#         },
#         {
#             "type": "para",
#             "marker": "s1",
#             "content": [
#                 "Naomi Becomes a Widow\n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "r",
#             "content": [
#                 "(1 Timothy 5:3\u201316)\n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "1",
#                     "sid": "RUT 1:1"
#                 },
#                 "In the days when the judges ruled, there was a famine in the land. And a certain man from Bethlehem in Judah, with his wife and two sons, went to reside in the land of Moab. \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "2",
#                     "sid": "RUT 1:2"
#                 },
#                 "The man\u2019s name was Elimelech, his wife\u2019s name was Naomi, and the names of his two sons were Mahlon and Chilion. They were Ephrathites from Bethlehem in Judah, and they entered the land of Moab and settled there. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "3",
#                     "sid": "RUT 1:3"
#                 },
#                 "Then Naomi\u2019s husband Elimelech died, and she was left with her two sons, \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "4",
#                     "sid": "RUT 1:4"
#                 },
#                 "who took Moabite women as their wives, one named Orpah and the other named Ruth. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 "And after they had lived in Moab about ten years, \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "5",
#                     "sid": "RUT 1:5"
#                 },
#                 "both Mahlon and Chilion also died, and Naomi was left without her two sons and without her husband. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "s1",
#             "content": [
#                 "Ruth\u2019s Loyalty to Naomi\n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "6",
#                     "sid": "RUT 1:6"
#                 },
#                 "When Naomi heard in Moab that the LORD had attended to His people by providing them with food, she and her daughters-in-law prepared to leave the land of Moab. \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "7",
#                     "sid": "RUT 1:7"
#                 },
#                 "Accompanied by her two daughters-in-law, she left the place where she had been living and set out on the road leading back to the land of Judah. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "8",
#                     "sid": "RUT 1:8"
#                 },
#                 "Then Naomi said to her two daughters-in-law, \u201cGo back, each of you to your mother\u2019s home. May the LORD show you loving devotion,",
#                 {
#                     "type": "note",
#                     "marker": "f",
#                     "content": [
#                         " ",
#                         {
#                             "type": "char",
#                             "marker": "fr",
#                             "content": [
#                                 "1:8 "
#                             ]
#                         },
#                         {
#                             "type": "char",
#                             "marker": "ft",
#                             "content": [
#                                 "Forms of the Hebrew chesed are translated here and in most cases throughout the Scriptures as loving devotion; the range of meaning includes love, goodness, kindness, faithfulness, and mercy, as well as loyalty to a covenant."
#                             ]
#                         }
#                     ],
#                     "caller": "+"
#                 },
#                 " as you have shown to your dead and to me. \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "9",
#                     "sid": "RUT 1:9"
#                 },
#                 "May the LORD enable each of you to find rest in the home of your new husband.\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 "And she kissed them as they wept aloud \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "10",
#                     "sid": "RUT 1:10"
#                 },
#                 "and said, \u201cSurely we will return with you to your people.\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "11",
#                     "sid": "RUT 1:11"
#                 },
#                 "But Naomi replied, \u201cReturn home, my daughters. Why would you go with me? Are there still sons in my womb to become your husbands? \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "12",
#                     "sid": "RUT 1:12"
#                 },
#                 "Return home, my daughters. Go on, for I am too old to have another husband. Even if I thought there was hope for me to have a husband tonight and to bear sons, \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "13",
#                     "sid": "RUT 1:13"
#                 },
#                 "would you wait for them to grow up? Would you refrain from having husbands? No, my daughters, it grieves me very much for your sakes that the hand of the LORD has gone out against me.\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "14",
#                     "sid": "RUT 1:14"
#                 },
#                 "Again they wept aloud, and Orpah kissed her mother-in-law goodbye, but Ruth clung to her. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "15",
#                     "sid": "RUT 1:15"
#                 },
#                 "\u201cLook,\u201d said Naomi, \u201cyour sister-in-law has gone back to her people and her gods; follow her back home.\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "16",
#                     "sid": "RUT 1:16"
#                 },
#                 "But Ruth replied: \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "q1",
#             "content": [
#                 "\u201cDo not urge me to leave you \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "q2",
#             "content": [
#                 "or to turn from following you. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "q1",
#             "content": [
#                 "For wherever you go, I will go, \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "q2",
#             "content": [
#                 "and wherever you live, I will live; \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "q1",
#             "content": [
#                 "your people will be my people, \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "q2",
#             "content": [
#                 "and your God will be my God. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "q1",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "17",
#                     "sid": "RUT 1:17"
#                 },
#                 "Where you die, I will die, \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "q2",
#             "content": [
#                 "and there I will be buried. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "q1",
#             "content": [
#                 "May the LORD punish me, \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "q2",
#             "content": [
#                 "and ever so severely, \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "q1",
#             "content": [
#                 "if anything but death \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "q2",
#             "content": [
#                 "separates you and me.\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "18",
#                     "sid": "RUT 1:18"
#                 },
#                 "When Naomi saw that Ruth was determined to go with her, she stopped trying to persuade her. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "s1",
#             "content": [
#                 "The Return to Bethlehem\n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "19",
#                     "sid": "RUT 1:19"
#                 },
#                 "So Naomi and Ruth traveled until they came to Bethlehem. When they entered Bethlehem, the whole city was stirred because of them, and the women of the city exclaimed, \u201cCan this be Naomi?\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "20",
#                     "sid": "RUT 1:20"
#                 },
#                 "\u201cDo not call me Naomi,",
#                 {
#                     "type": "note",
#                     "marker": "f",
#                     "content": [
#                         " ",
#                         {
#                             "type": "char",
#                             "marker": "fr",
#                             "content": [
#                                 "1:20 "
#                             ]
#                         },
#                         {
#                             "type": "char",
#                             "marker": "ft",
#                             "content": [
#                                 "Naomi means pleasant."
#                             ]
#                         }
#                     ],
#                     "caller": "+"
#                 },
#                 "\u201d she replied. \u201cCall me Mara,",
#                 {
#                     "type": "note",
#                     "marker": "f",
#                     "content": [
#                         " ",
#                         {
#                             "type": "char",
#                             "marker": "fr",
#                             "content": [
#                                 "1:20 "
#                             ]
#                         },
#                         {
#                             "type": "char",
#                             "marker": "ft",
#                             "content": [
#                                 "Mara means bitter."
#                             ]
#                         }
#                     ],
#                     "caller": "+"
#                 },
#                 " because the Almighty ",
#                 {
#                     "type": "note",
#                     "marker": "f",
#                     "content": [
#                         " ",
#                         {
#                             "type": "char",
#                             "marker": "fr",
#                             "content": [
#                                 "1:20 "
#                             ]
#                         },
#                         {
#                             "type": "char",
#                             "marker": "ft",
#                             "content": [
#                                 "Hebrew Shaddai; also in verse 21"
#                             ]
#                         }
#                     ],
#                     "caller": "+"
#                 },
#                 " has dealt quite bitterly with me. \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "21",
#                     "sid": "RUT 1:21"
#                 },
#                 "I went away full, but the LORD has brought me back empty. Why call me Naomi? After all, the LORD has testified against me, and the Almighty has afflicted me.\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "22",
#                     "sid": "RUT 1:22"
#                 },
#                 "So Naomi returned from the land of Moab with her daughter-in-law Ruth the Moabitess. And they arrived in Bethlehem at the beginning of the barley harvest. \n"
#             ]
#         },
#         {
#             "type": "chapter",
#             "marker": "c",
#             "number": "2",
#             "sid": "RUT 2"
#         },
#         {
#             "type": "para",
#             "marker": "s1",
#             "content": [
#                 "Boaz Meets Ruth\n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "1",
#                     "sid": "RUT 2:1"
#                 },
#                 "Now Naomi had a relative on her husband\u2019s side, a prominent man of noble character from the clan of Elimelech, whose name was Boaz. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "2",
#                     "sid": "RUT 2:2"
#                 },
#                 "And Ruth the Moabitess said to Naomi, \u201cPlease let me go into the fields and glean heads of grain after someone in whose sight I may find favor.\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 "\u201cGo ahead, my daughter,\u201d Naomi replied. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "3",
#                     "sid": "RUT 2:3"
#                 },
#                 "So Ruth departed and went out into the field and gleaned after the harvesters. And she happened to come to the part of the field belonging to Boaz, who was from the clan of Elimelech. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "4",
#                     "sid": "RUT 2:4"
#                 },
#                 "Just then Boaz arrived from Bethlehem and said to the harvesters, \u201cThe LORD be with you.\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 "\u201cThe LORD bless you,\u201d they replied. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "5",
#                     "sid": "RUT 2:5"
#                 },
#                 "And Boaz asked the foreman of his harvesters, \u201cWhose young woman is this?\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "6",
#                     "sid": "RUT 2:6"
#                 },
#                 "The foreman answered, \u201cShe is the Moabitess who returned with Naomi from the land of Moab. \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "7",
#                     "sid": "RUT 2:7"
#                 },
#                 "She has said, \u2018Please let me glean and gather among the sheaves after the harvesters.\u2019 So she came out and has continued from morning until now, except that she rested a short time in the shelter.\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "8",
#                     "sid": "RUT 2:8"
#                 },
#                 "Then Boaz said to Ruth, \u201cListen, my daughter. Do not go and glean in another field, and do not go away from this place, but stay here close to my servant girls. \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "9",
#                     "sid": "RUT 2:9"
#                 },
#                 "Let your eyes be on the field they are harvesting, and follow along after these girls. Indeed, I have ordered the young men not to touch you. And when you are thirsty, go and drink from the jars the young men have filled.\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "10",
#                     "sid": "RUT 2:10"
#                 },
#                 "At this, she fell on her face, bowing low to the ground, and said to him, \u201cWhy have I found such favor in your eyes that you should take notice of me, even though I am a foreigner?\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "11",
#                     "sid": "RUT 2:11"
#                 },
#                 "Boaz replied, \u201cI have been made fully aware of all you have done for your mother-in-law since the death of your husband, how you left your father and mother and the land of your birth, and how you came to a people you did not know before. \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "12",
#                     "sid": "RUT 2:12"
#                 },
#                 "May the LORD repay your work, and may you receive a rich reward from the LORD, the God of Israel, under whose wings you have taken refuge.\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "13",
#                     "sid": "RUT 2:13"
#                 },
#                 "\u201cMy lord,\u201d she said, \u201cmay I continue to find favor in your eyes, for you have comforted and spoken kindly to your maidservant, though I am not like one of your servant girls.\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "14",
#                     "sid": "RUT 2:14"
#                 },
#                 "At mealtime Boaz said to her, \u201cCome over here; have some bread and dip it into the vinegar sauce.\u201d So she sat down beside the harvesters, and he offered her roasted grain, and she ate and was satisfied and had some left over. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "15",
#                     "sid": "RUT 2:15"
#                 },
#                 "When Ruth got up to glean, Boaz ordered his young men, \u201cEven if she gathers among the sheaves, do not insult her. \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "16",
#                     "sid": "RUT 2:16"
#                 },
#                 "Rather, pull out for her some stalks from the bundles and leave them for her to gather. Do not rebuke her.\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "17",
#                     "sid": "RUT 2:17"
#                 },
#                 "So Ruth gathered grain in the field until evening. And when she beat out what she had gleaned, it was about an ephah of barley.",
#                 {
#                     "type": "note",
#                     "marker": "f",
#                     "content": [
#                         " ",
#                         {
#                             "type": "char",
#                             "marker": "fr",
#                             "content": [
#                                 "2:17 "
#                             ]
#                         },
#                         {
#                             "type": "char",
#                             "marker": "ft",
#                             "content": [
#                                 "An ephah is approximately 20 dry quarts or 22 liters (probably about 29 pounds or 13.2 kilograms of barley)."
#                             ]
#                         }
#                     ],
#                     "caller": "+"
#                 },
#                 " \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "18",
#                     "sid": "RUT 2:18"
#                 },
#                 "She picked up the grain and went into the town, where her mother-in-law saw what she had gleaned. And she brought out what she had saved from her meal and gave it to Naomi. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "19",
#                     "sid": "RUT 2:19"
#                 },
#                 "Then her mother-in-law asked her, \u201cWhere did you glean today, and where did you work? Blessed be the man who noticed you.\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 "So she told her mother-in-law where she had worked. \u201cThe name of the man I worked with today is Boaz,\u201d she said. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "20",
#                     "sid": "RUT 2:20"
#                 },
#                 "Then Naomi said to her daughter-in-law, \u201cMay he be blessed by the LORD, who has not withdrawn His kindness from the living or the dead.\u201d Naomi continued, \u201cThe man is a close relative. He is one of our kinsman-redeemers.",
#                 {
#                     "type": "note",
#                     "marker": "f",
#                     "content": [
#                         " ",
#                         {
#                             "type": "char",
#                             "marker": "fr",
#                             "content": [
#                                 "2:20 "
#                             ]
#                         },
#                         {
#                             "type": "char",
#                             "marker": "ft",
#                             "content": [
#                                 "The Hebrew word for kinsman-redeemer or guardian-redeemer is a legal term for the kinsman who redeems or vindicates a relative; see Leviticus 25:25\u201355."
#                             ]
#                         }
#                     ],
#                     "caller": "+"
#                 },
#                 "\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "21",
#                     "sid": "RUT 2:21"
#                 },
#                 "Then Ruth the Moabitess said, \u201cHe also told me, \u2018Stay with my young men until they have finished gathering all my harvest.\u2019\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "22",
#                     "sid": "RUT 2:22"
#                 },
#                 "And Naomi said to her daughter-in-law Ruth, \u201cMy daughter, it is good for you to work with his young women, so that nothing will happen to you in another field.\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "23",
#                     "sid": "RUT 2:23"
#                 },
#                 "So Ruth stayed close to the servant girls of Boaz to glean grain until the barley and wheat harvests were finished. And she lived with her mother-in-law. \n"
#             ]
#         },
#         {
#             "type": "chapter",
#             "marker": "c",
#             "number": "3",
#             "sid": "RUT 3"
#         },
#         {
#             "type": "para",
#             "marker": "s1",
#             "content": [
#                 "Ruth\u2019s Redemption Assured\n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "1",
#                     "sid": "RUT 3:1"
#                 },
#                 "One day Ruth\u2019s mother-in-law Naomi said to her, \u201cMy daughter, should I not seek a resting place for you, that it may be well with you? \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "2",
#                     "sid": "RUT 3:2"
#                 },
#                 "Now is not Boaz, with whose servant girls you have been working, a relative of ours? In fact, tonight he is winnowing barley on the threshing floor. \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "3",
#                     "sid": "RUT 3:3"
#                 },
#                 "Therefore wash yourself, put on perfume, and wear your best clothes. Go down to the threshing floor, but do not let the man know you are there until he has finished eating and drinking. \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "4",
#                     "sid": "RUT 3:4"
#                 },
#                 "When he lies down, note the place where he lies. Then go in and uncover his feet, and lie down, and he will explain to you what you should do.\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "5",
#                     "sid": "RUT 3:5"
#                 },
#                 "\u201cI will do everything you say,\u201d Ruth answered. \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "6",
#                     "sid": "RUT 3:6"
#                 },
#                 "So she went down to the threshing floor and did everything her mother-in-law had instructed her to do. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "7",
#                     "sid": "RUT 3:7"
#                 },
#                 "After Boaz had finished eating and drinking and was in good spirits, he went to lie down at the end of the heap of grain. Then Ruth went in secretly, uncovered his feet, and lay down. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "8",
#                     "sid": "RUT 3:8"
#                 },
#                 "At midnight, Boaz was startled, turned over, and there lying at his feet was a woman! \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "9",
#                     "sid": "RUT 3:9"
#                 },
#                 "\u201cWho are you?\u201d he asked. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 "\u201cI am your servant Ruth,\u201d she replied. \u201cSpread the corner of your garment ",
#                 {
#                     "type": "note",
#                     "marker": "f",
#                     "content": [
#                         " ",
#                         {
#                             "type": "char",
#                             "marker": "fr",
#                             "content": [
#                                 "3:9 "
#                             ]
#                         },
#                         {
#                             "type": "char",
#                             "marker": "ft",
#                             "content": [
#                                 "Or Spread your wing; the word for wing can also mean corner of a garment; see Ruth 2:12."
#                             ]
#                         }
#                     ],
#                     "caller": "+"
#                 },
#                 " over me, for you are a kinsman-redeemer.",
#                 {
#                     "type": "note",
#                     "marker": "f",
#                     "content": [
#                         " ",
#                         {
#                             "type": "char",
#                             "marker": "fr",
#                             "content": [
#                                 "3:9 "
#                             ]
#                         },
#                         {
#                             "type": "char",
#                             "marker": "ft",
#                             "content": [
#                                 "The Hebrew word for kinsman-redeemer or guardian-redeemer is a legal term for the kinsman who redeems or vindicates a relative; similarly in verses 12 and 13; see Leviticus 25:25\u201355."
#                             ]
#                         }
#                     ],
#                     "caller": "+"
#                 },
#                 "\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "10",
#                     "sid": "RUT 3:10"
#                 },
#                 "Then Boaz said, \u201cMay the LORD bless you, my daughter. You have shown more kindness now than before, because you have not run after the younger men, whether rich or poor. \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "11",
#                     "sid": "RUT 3:11"
#                 },
#                 "And now do not be afraid, my daughter. I will do for you whatever you request, since all my fellow townspeople know that you are a woman of noble character. \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "12",
#                     "sid": "RUT 3:12"
#                 },
#                 "Yes, it is true that I am a kinsman-redeemer, but there is a redeemer nearer than I.",
#                 {
#                     "type": "note",
#                     "marker": "f",
#                     "content": [
#                         " ",
#                         {
#                             "type": "char",
#                             "marker": "fr",
#                             "content": [
#                                 "3:12 "
#                             ]
#                         },
#                         {
#                             "type": "char",
#                             "marker": "ft",
#                             "content": [
#                                 "That is, more closely related"
#                             ]
#                         }
#                     ],
#                     "caller": "+"
#                 },
#                 " \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "13",
#                     "sid": "RUT 3:13"
#                 },
#                 "Stay here tonight, and in the morning, if he wants to redeem you, good. Let him redeem you. But if he does not want to redeem you, as surely as the LORD lives, I will. Now lie here until morning.\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "14",
#                     "sid": "RUT 3:14"
#                 },
#                 "So she lay down at his feet until morning, but she got up before anyone else could recognize her. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 "Then Boaz said, \u201cDo not let it be known that a woman came to the threshing floor.\u201d \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "15",
#                     "sid": "RUT 3:15"
#                 },
#                 "And he told her, \u201cBring the shawl you are wearing and hold it out.\u201d When she did so, he shoveled six measures of barley ",
#                 {
#                     "type": "note",
#                     "marker": "f",
#                     "content": [
#                         " ",
#                         {
#                             "type": "char",
#                             "marker": "fr",
#                             "content": [
#                                 "3:15 "
#                             ]
#                         },
#                         {
#                             "type": "char",
#                             "marker": "ft",
#                             "content": [
#                                 "Possibly six seahs (two ephahs), or approximately 39.6 dry quarts or 43.8 liters (about 58 pounds or 26.3 kilograms of barley) "
#                             ]
#                         }
#                     ],
#                     "caller": "+"
#                 },
#                 " into her shawl. Then he went ",
#                 {
#                     "type": "note",
#                     "marker": "f",
#                     "content": [
#                         " ",
#                         {
#                             "type": "char",
#                             "marker": "fr",
#                             "content": [
#                                 "3:15 "
#                             ]
#                         },
#                         {
#                             "type": "char",
#                             "marker": "ft",
#                             "content": [
#                                 "Most Hebrew manuscripts; many Hebrew manuscripts, Vulgate, and Syriac she went"
#                             ]
#                         }
#                     ],
#                     "caller": "+"
#                 },
#                 " into the city. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "16",
#                     "sid": "RUT 3:16"
#                 },
#                 "When Ruth returned to her mother-in-law, Naomi asked her, \u201cHow did it go, my daughter?\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 "Then Ruth told her all that Boaz had done for her. \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "17",
#                     "sid": "RUT 3:17"
#                 },
#                 "And she said, \u201cHe gave me these six measures of barley, for he said, \u2018Do not go back to your mother-in-law empty-handed.\u2019\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "18",
#                     "sid": "RUT 3:18"
#                 },
#                 "\u201cWait, my daughter,\u201d said Naomi, \u201cuntil you find out how things go, for he will not rest unless he has resolved the matter today.\u201d \n"
#             ]
#         },
#         {
#             "type": "chapter",
#             "marker": "c",
#             "number": "4",
#             "sid": "RUT 4"
#         },
#         {
#             "type": "para",
#             "marker": "s1",
#             "content": [
#                 "Boaz Redeems Ruth\n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "1",
#                     "sid": "RUT 4:1"
#                 },
#                 "Meanwhile, Boaz went to the gate and sat down there. Soon the kinsman-redeemer ",
#                 {
#                     "type": "note",
#                     "marker": "f",
#                     "content": [
#                         " ",
#                         {
#                             "type": "char",
#                             "marker": "fr",
#                             "content": [
#                                 "4:1 "
#                             ]
#                         },
#                         {
#                             "type": "char",
#                             "marker": "ft",
#                             "content": [
#                                 "The Hebrew word for kinsman-redeemer or guardian-redeemer is a legal term for the kinsman who redeems or vindicates a relative; also in verses 3, 6, 8, and 14; see Leviticus 25:25\u201355."
#                             ]
#                         }
#                     ],
#                     "caller": "+"
#                 },
#                 " of whom he had spoken came along, and Boaz said, \u201cCome over here, my friend, and sit down.\u201d So he went over and sat down. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "2",
#                     "sid": "RUT 4:2"
#                 },
#                 "Then Boaz took ten of the elders of the city and said, \u201cSit here,\u201d and they did so. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "3",
#                     "sid": "RUT 4:3"
#                 },
#                 "And he said to the kinsman-redeemer, \u201cNaomi, who has returned from the land of Moab, is selling the piece of land that belonged to our brother Elimelech. \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "4",
#                     "sid": "RUT 4:4"
#                 },
#                 "I thought I should inform you that you may buy it back in the presence of those seated here and in the presence of the elders of my people. If you want to redeem it, do so. But if you ",
#                 {
#                     "type": "note",
#                     "marker": "f",
#                     "content": [
#                         " ",
#                         {
#                             "type": "char",
#                             "marker": "fr",
#                             "content": [
#                                 "4:4 "
#                             ]
#                         },
#                         {
#                             "type": "char",
#                             "marker": "ft",
#                             "content": [
#                                 "Many Hebrew manuscripts, LXX, Vulgate, and Syriac; most Hebrew manuscripts he"
#                             ]
#                         }
#                     ],
#                     "caller": "+"
#                 },
#                 " will not redeem it, tell me so I may know, because there is no one but you to redeem it, and I am next after you.\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 "\u201cI will redeem it,\u201d he replied. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "5",
#                     "sid": "RUT 4:5"
#                 },
#                 "Then Boaz said, \u201cOn the day you buy the land from Naomi and also from Ruth the Moabitess, you must also acquire the widow of the deceased in order to raise up the name of the deceased on his inheritance.\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "6",
#                     "sid": "RUT 4:6"
#                 },
#                 "The kinsman-redeemer replied, \u201cI cannot redeem it myself, or I would jeopardize my own inheritance. Take my right of redemption, because I cannot redeem it.\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "7",
#                     "sid": "RUT 4:7"
#                 },
#                 "Now in former times in Israel, concerning the redemption or exchange of property, to make any matter legally binding a man would remove his sandal and give it to the other party, and this was a confirmation in Israel. \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "8",
#                     "sid": "RUT 4:8"
#                 },
#                 "So the kinsman-redeemer removed his sandal and said to Boaz, \u201cBuy it for yourself.\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "9",
#                     "sid": "RUT 4:9"
#                 },
#                 "At this, Boaz said to the elders and all the people, \u201cYou are witnesses today that I am buying from Naomi all that belonged to Elimelech, Chilion, and Mahlon. \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "10",
#                     "sid": "RUT 4:10"
#                 },
#                 "Moreover, I have acquired Ruth the Moabitess, Mahlon\u2019s widow, as my wife, to raise up the name of the deceased through his inheritance, so that his name will not disappear from among his brothers or from the gate of his home. You are witnesses today.\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "11",
#                     "sid": "RUT 4:11"
#                 },
#                 "\u201cWe are witnesses,\u201d said the elders and all the people at the gate. \u201cMay the LORD make the woman entering your home like Rachel and Leah, who together built up the house of Israel. May you be prosperous in Ephrathah and famous in Bethlehem. \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "12",
#                     "sid": "RUT 4:12"
#                 },
#                 "And may your house become like the house of Perez, whom Tamar bore to Judah, because of the offspring the LORD will give you by this young woman.\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "s1",
#             "content": [
#                 "Boaz Marries Ruth\n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "13",
#                     "sid": "RUT 4:13"
#                 },
#                 "So Boaz took Ruth, and she became his wife. And when he had relations with her, the LORD enabled her to conceive, and she gave birth to a son. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "14",
#                     "sid": "RUT 4:14"
#                 },
#                 "Then the women said to Naomi, \u201cBlessed be the LORD, who has not left you this day without a kinsman-redeemer. May his name become famous in Israel. \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "15",
#                     "sid": "RUT 4:15"
#                 },
#                 "He will renew your life and sustain you in your old age. For your daughter-in-law, who loves you and is better to you than seven sons, has given him birth.\u201d \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "16",
#                     "sid": "RUT 4:16"
#                 },
#                 "And Naomi took the child, placed him on her lap, and became a nurse to him. \n",
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "17",
#                     "sid": "RUT 4:17"
#                 },
#                 "The neighbor women said, \u201cA son has been born to Naomi,\u201d and they named him Obed. He became the father of Jesse, the father of David. \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "s1",
#             "content": [
#                 "The Line of David\n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "r",
#             "content": [
#                 "(Matthew 1:1\u201317; Luke 3:23\u201338)\n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "m",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "18",
#                     "sid": "RUT 4:18"
#                 },
#                 "Now these are the generations of Perez: \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "li1",
#             "content": [
#                 "Perez was the father of Hezron, \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "li1",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "19",
#                     "sid": "RUT 4:19"
#                 },
#                 "Hezron was the father of Ram, \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "li1",
#             "content": [
#                 "Ram was the father of Amminadab, \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "li1",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "20",
#                     "sid": "RUT 4:20"
#                 },
#                 "Amminadab was the father of Nahshon, \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "li1",
#             "content": [
#                 "Nahshon was the father of Salmon,",
#                 {
#                     "type": "note",
#                     "marker": "f",
#                     "content": [
#                         " ",
#                         {
#                             "type": "char",
#                             "marker": "fr",
#                             "content": [
#                                 "4:20 "
#                             ]
#                         },
#                         {
#                             "type": "char",
#                             "marker": "ft",
#                             "content": [
#                                 "A few Hebrew manuscripts, some LXX manuscripts, and Vulgate (see also verse 21 and LXX of 1 Chronicles 2:11); most Hebrew manuscripts Salma"
#                             ]
#                         }
#                     ],
#                     "caller": "+"
#                 },
#                 " \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "li1",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "21",
#                     "sid": "RUT 4:21"
#                 },
#                 "Salmon was the father of Boaz, \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "li1",
#             "content": [
#                 "Boaz was the father of Obed, \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "li1",
#             "content": [
#                 {
#                     "type": "verse",
#                     "marker": "v",
#                     "number": "22",
#                     "sid": "RUT 4:22"
#                 },
#                 "Obed was the father of Jesse, \n"
#             ]
#         },
#         {
#             "type": "para",
#             "marker": "b"
#         },
#         {
#             "type": "para",
#             "marker": "li1",
#             "content": [
#                 "and Jesse was the father of David. "
#             ]
#         }
#     ]
# }

# %% [markdown]
# Single JSON file

# %%
import json

# Save the entire Bible data to a single JSON file
output_file = "bible3.json"
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(bible_data, f, ensure_ascii=False, indent=2)

print(f"Bible data saved to {output_file}")
# Out:
# Bible data saved to bible.json

# %% [markdown]
# Multiple JSON Files (One Per Book)

# %%
import json
import os

# Create a folder for the JSON files
output_dir = "bible_json"
os.makedirs(output_dir, exist_ok=True)

# Save each book as an individual JSON file
for file_name, book_data in bible_data.items():
    book_name = os.path.splitext(os.path.basename(file_name))[0]
    output_file = os.path.join(output_dir, f"{book_name}.json")
    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(book_data, f, ensure_ascii=False, indent=2)

print(f"Bible data saved to {output_dir}")
# Out:
# Bible data saved to bible_json

# %% [markdown]
# Full flow

# %%
import json
import os

from usfm_grammar import USFMParser

# Canonical Order for Bible Books
CANONICAL_ORDER = [
    # Torah (Pentateuch)
    "01GENBSB",
    "02EXOBSB",
    "03LEVBSB",
    "04NUMBSB",
    "05DEUBSB",
    # Historical Books
    "06JOSBSB",
    "07JDGBSB",
    "08RUTBSB",
    "091SABSB",
    "102SABSB",
    "111KIBSB",
    "122KIBSB",
    "131CHBSB",
    "142CHBSB",
    "15EZRBSB",
    "16NEHBSB",
    "17ESTBSB",
    # Wisdom Literature
    "18JOBBSB",
    "19PSABSB",
    "20PROBSB",
    "21ECCBSB",
    "22SNGBSB",
    # Major Prophets
    "23ISABSB",
    "24JERBSB",
    "25LAMBSB",
    "26EZKBSB",
    "27DANBSB",
    # Minor Prophets
    "28HOSBSB",
    "29JOLBSB",
    "30AMOBSB",
    "31OBABSB",
    "32JONBSB",
    "33MICBSB",
    "34NAMBSB",
    "35HABBSB",
    "36ZEPBSB",
    "37HAGBSB",
    "38ZECBSB",
    "39MALBSB",
    # New Testament
    "41MATBSB",
    "42MRKBSB",
    "43LUKBSB",
    "44JHNBSB",
    "45ACTBSB",
    "46ROMBSB",
    "471COBSB",
    "482COBSB",
    "49GALBSB",
    "50EPHBSB",
    "51PHPBSB",
    "52COLBSB",
    "531THBSB",
    "542THBSB",
    "551TIBSB",
    "562TIBSB",
    "57TITBSB",
    "58PHMBSB",
    "59HEBBSB",
    "60JASBSB",
    "611PEBSB",
    "622PEBSB",
    "631JNBSB",
    "642JNBSB",
    "653JNBSB",
    "66JUDBSB",
    "67REVBSB",
]

# Folder containing USFM files
USFM_FOLDER = "data/bsb_usfm"

# Initialize ordered Bible data
ordered_bible_data = {}

# Iterate through canonical order to preserve sequence
for book_code in CANONICAL_ORDER:
    file_path = os.path.join(USFM_FOLDER, f"{book_code}.usfm")
    if os.path.exists(file_path):
        with open(file_path, "r", encoding="utf-8") as f:
            content = f.read()
            parser = USFMParser(content)

            # Check for errors
            if parser.errors:
                print(f"Errors in file {file_path}: {parser.errors}")
                continue

            usj_data = parser.to_usj()

            # Add parsed data to ordered_bible_data
            ordered_bible_data[book_code] = usj_data

# Save the ordered Bible data to a JSON file
output_file = "ordered_bible.json"
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(ordered_bible_data, f, ensure_ascii=False, indent=2)

print(f"Ordered Bible data saved to {output_file}")
# Out:
# Errors in file data/bsb_usfm/19PSABSB.usfm: [('At Point(row=217, column=179)', 'A Psalm of David.'), ('At Point(row=217, column=195)', '.'), ('At Point(row=256, column=87)', 'of David, which he sang to the LORD concerning the words of Cush, a Benjamite.'), ('At Point(row=256, column=95)', ','), ('At Point(row=256, column=151)', ','), ('At Point(row=256, column=164)', '.'), ('At Point(row=322, column=145)', 'A Psalm of David.'), ('At Point(row=322, column=161)', '.'), ('At Point(row=543, column=152)', 'A Psalm of David.'), ('At Point(row=543, column=168)', '.'), ('At Point(row=673, column=120)', 'of David.'), ('At Point(row=673, column=128)', '.'), ('At Point(row=1904, column=159)', 'so that the king drove him away.'), ('At Point(row=1904, column=190)', '.'), ('At Point(row=2675, column=171)', 'of the sons of Korah.'), ('At Point(row=2675, column=191)', '.'), ('At Point(row=2773, column=204)', 'of the sons of Korah. A love song.'), ('At Point(row=2773, column=224)', '.'), ('At Point(row=2773, column=237)', '.'), ('At Point(row=2842, column=170)', 'A song.'), ('At Point(row=2842, column=176)', '.'), ('At Point(row=3221, column=171)', 'of David. After Doeg the Edomite went to Saul and told him, “David has gone to the house of Ahimelech.”'), ('At Point(row=3221, column=179)', '.'), ('At Point(row=3221, column=229)', ', “'), ('At Point(row=3221, column=274)', '.”'), ('At Point(row=3266, column=139)', 'A Maskil'), ('At Point(row=3266, column=286)', 'of David.'), ('At Point(row=3266, column=294)', '.'), ('At Point(row=3308, column=198)', 'of David. When the Ziphites went to Saul and said, “Is David not hiding among us?”'), ('At Point(row=3308, column=206)', '.'), ('At Point(row=3308, column=247)', ', “'), ('At Point(row=3308, column=280)', '?”'), ('At Point(row=3337, column=198)', 'of David.'), ('At Point(row=3337, column=206)', '.'), ('At Point(row=3435, column=180)', 'of David, when the Philistines seized him in Gath.'), ('At Point(row=3435, column=188)', ','), ('At Point(row=3435, column=229)', '.'), ('At Point(row=3493, column=172)', 'of David, when he fled from Saul into the cave.'), ('At Point(row=3493, column=180)', ','), ('At Point(row=3493, column=218)', '.'), ('At Point(row=3545, column=172)', 'of David.'), ('At Point(row=3545, column=180)', '.'), ('At Point(row=3594, column=172)', 'of David, when Saul sent men to watch David’s house in order to kill him.'), ('At Point(row=3594, column=180)', ','), ('At Point(row=3594, column=215)', '’'), ('At Point(row=3594, column=246)', '.'), ('At Point(row=3671, column=182)', 'of David for instruction. When he fought Aram-naharaim'), ('At Point(row=3671, column=206)', '.'), ('At Point(row=3671, column=227)', '-'), ('At Point(row=3671, column=410)', 'and Aram-zobah,'), ('At Point(row=3671, column=418)', '-'), ('At Point(row=3671, column=424)', ','), ('At Point(row=3671, column=486)', 'and Joab returned and struck down 12,000 Edomites in the Valley of Salt.'), ('At Point(row=3671, column=522)', ','), ('At Point(row=3671, column=557)', '.'), ('At Point(row=4668, column=150)', 'of Asaph.'), ('At Point(row=4668, column=158)', '.'), ('At Point(row=4919, column=150)', 'of Asaph.'), ('At Point(row=4919, column=158)', '.'), ('At Point(row=5311, column=145)', 'Of Asaph.'), ('At Point(row=5311, column=153)', '.'), ('At Point(row=5469, column=145)', 'A Psalm of the sons of Korah.'), ('At Point(row=5469, column=173)', '.'), ('At Point(row=5673, column=195)', 'A Maskil'), ('At Point(row=5673, column=342)', 'of Heman the Ezrahite.'), ('At Point(row=5673, column=363)', '.'), ('At Point(row=5742, column=150)', 'of Ethan the Ezrahite.'), ('At Point(row=5742, column=171)', '.'), ('At Point(row=9330, column=151)', 'of David, when he was in the cave. A prayer.'), ('At Point(row=9330, column=159)', ','), ('At Point(row=9330, column=184)', '.'), ('At Point(row=9330, column=194)', '.')]
# Errors in file data/bsb_usfm/35HABBSB.usfm: [('At Point(row=306, column=0)', '\\it For the choirmaster. With stringed instruments.\n\\it*'), ('At Point(row=306, column=23)', '.'), ('At Point(row=306, column=50)', '.')]
# Errors in file data/bsb_usfm/38ZECBSB.usfm: [('At Point(row=553, column=0)', '\\d\n\\v 1 This is the burden of the word of the LORD concerning Israel.'), ('At Point(row=554, column=65)', '.')]
# Ordered Bible data saved to ordered_bible.json
